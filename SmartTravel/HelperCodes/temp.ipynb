# %%
import requests
import pandas as pd
import time

API_KEY = "AIzaSyBv7NCrjXAorMab8LAFCA302wRNMATEboo"
CSV_PATH = "C:/Users/kevin/CS 411/SmartTravel/DataSheets/Location_dataset.csv"
OUTPUT_CSV = "attractions_google_v1.csv"

# Load city names (first 50)
df = pd.read_csv(CSV_PATH, sep=';').head(50)

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "places.displayName,places.formattedAddress,places.rating,places.priceLevel,places.types,places.location"
}

results = []

for idx, row in df.iterrows():
    city = row['name']
    country = row['country']
    location_id = row['location_id']

    query = f"Tourist attractions in {city}, {country}"
    body = {
        "textQuery": query,
        "pageSize": 10
    }

    print(f"🔍 {idx + 1}/50: {query}")

    try:
        response = requests.post(
            "https://places.googleapis.com/v1/places:searchText",
            headers=headers,
            json=body
        )
        data = response.json()

        if "places" in data:
            for place in data["places"]:
                results.append({
                    "location_id": location_id,
                    "name": place.get("displayName", {}).get("text"),
                    "category": place.get("types", [None])[0],
                    "rating": place.get("rating"),
                    "price_level": place.get("priceLevel"),
                    "lat": place.get("location", {}).get("latitude"),
                    "lon": place.get("location", {}).get("longitude"),
                    "source": "Google Places New"
                })

    except Exception as e:
        print(f"❌ Error: {e}")

    time.sleep(1)

# Save results
out_df = pd.DataFrame(results)
out_df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ Done! Saved {len(out_df)} places to {OUTPUT_CSV}")
# Out:
# 🔍 1/50: Tourist attractions in Tokyo, Japan
# 🔍 2/50: Tourist attractions in Jakarta, Indonesia
# 🔍 3/50: Tourist attractions in Delhi, India
# 🔍 4/50: Tourist attractions in Guangzhou, China
# 🔍 5/50: Tourist attractions in Mumbai, India
# 🔍 6/50: Tourist attractions in Manila, Philippines
# 🔍 7/50: Tourist attractions in Shanghai, China
# 🔍 8/50: Tourist attractions in São Paulo, Brazil
# 🔍 9/50: Tourist attractions in Seoul, Korea, South
# 🔍 10/50: Tourist attractions in Mexico City, Mexico
# 🔍 11/50: Tourist attractions in Kolkāta, India
# 🔍 12/50: Tourist attractions in Cairo, Egypt
# 🔍 13/50: Tourist attractions in Karachi, Pakistan
# 🔍 14/50: Tourist attractions in Dhaka, Bangladesh
# 🔍 15/50: Tourist attractions in New York, United States
# 🔍 16/50: Tourist attractions in Beijing, China
# 🔍 17/50: Tourist attractions in Bangkok, Thailand
# 🔍 18/50: Tourist attractions in Shenzhen, China
# 🔍 19/50: Tourist attractions in Moscow, Russia
# 🔍 20/50: Tourist attractions in Buenos Aires, Argentina
# 🔍 21/50: Tourist attractions in Lagos, Nigeria
# 🔍 22/50: Tourist attractions in Bangalore, India
# 🔍 23/50: Tourist attractions in Ho Chi Minh City, Vietnam
# 🔍 24/50: Tourist attractions in Ōsaka, Japan
# 🔍 25/50: Tourist attractions in Chengdu, China
# 🔍 26/50: Tourist attractions in Istanbul, Turkey
# 🔍 27/50: Tourist attractions in Tehran, Iran
# 🔍 28/50: Tourist attractions in Kinshasa, Congo (Kinshasa)
# 🔍 29/50: Tourist attractions in Rio de Janeiro, Brazil
# 🔍 30/50: Tourist attractions in Chennai, India
# 🔍 31/50: Tourist attractions in Xi’an, China
# 🔍 32/50: Tourist attractions in Lahore, Pakistan
# 🔍 33/50: Tourist attractions in Chongqing, China
# 🔍 34/50: Tourist attractions in Los Angeles, United States
# 🔍 35/50: Tourist attractions in London, United Kingdom
# 🔍 36/50: Tourist attractions in Paris, France
# 🔍 37/50: Tourist attractions in Linyi, China
# 🔍 38/50: Tourist attractions in Dongguan, China
# 🔍 39/50: Tourist attractions in Baoding, China
# 🔍 40/50: Tourist attractions in Hyderābād, India
# 🔍 41/50: Tourist attractions in Tianjin, China
# 🔍 42/50: Tourist attractions in Lima, Peru
# 🔍 43/50: Tourist attractions in Wuhan, China
# 🔍 44/50: Tourist attractions in Nanyang, China
# 🔍 45/50: Tourist attractions in Hangzhou, China
# 🔍 46/50: Tourist attractions in Nagoya, Japan
# 🔍 47/50: Tourist attractions in Luanda, Angola
# 🔍 48/50: Tourist attractions in Foshan, China
# 🔍 49/50: Tourist attractions in Kuala Lumpur, Malaysia
# 🔍 50/50: Tourist attractions in Zhoukou, China
#
# ✅ Done! Saved 500 places to attractions_google_v1.csv
